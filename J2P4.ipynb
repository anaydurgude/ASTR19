# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#a=np.random.default_rng(triangular(0,1,5,1000))

rng = np.random.default_rng()
dist = rng.triangular(0,1,5,1000)
plt.hist(dist, bins=100, density=True)
plt.savefig("triangulardist.pdf")
